# %% [markdown]
# # Funciones Cadena

# %% [markdown]
# ## Nivel I

# %% [markdown]
# **1.- Escribir un programa que dado la base y la altura no calcule el área del rectángulo.**

# %%
## Resolver Aqui
# Zona de Inputs

# Zona de Logica

# Zona de Respuesta
print()
# Out:
# Ingrese la Base: 4.5
# Ingrese la Altura: 5.2
# El area del rectangulo es: 23.400000000000002

# %% [markdown]
# **2.- Escribir un programa que dado la base y la altura no calcule el área del triángulo.**

# %%
## Resolver Aqui
# Zona de Inputs

# Zona de Logica

# Zona de Respuesta
print()

# %% [markdown]
# **3.- Escribir un programa que dado el diámetro de una circunferencia, calcule el área del ciurcul y su perímetro.**

# %%
## Resolver Aqui
# Out:
# 3.14

# %% [markdown]
# **4.- Dada una cantidad de kilómetros recorridos por una motocicleta y la cantidad de litros de gasolina consumidos, calcule el consumo de combustible por kilómetro**

# %%
## Resolver Aqui

# %% [markdown]
# **5.- Dada una temperatura en Farenheit, calcule su equivalente en grados Celsius, la formula es la siguiente: Celsuis = 5/9 * ( Farenheit – 32 )**

# %%
## Resolver Aqui

# %% [markdown]
# **6.- Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas.
# Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda.
# Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.**

# %%
## Resolver Aqui

# %% [markdown]
# ## Nivel II

# %% [markdown]
# **7.- Determinar la distancia de dos puntos en el espacio [x1, x2, x3], [y1, y2, y3]**

# %%
## Resolver Aqui

# %% [markdown]
# **8.- Dado un diccionario que almacena los tipos de cambio, el monto en soles y el tipo de cambio al que se desea convertir, calcular el monto final**

# %%
## Resolver Aqui

# Zona de inputs
montoInicial = 
dicTC = {'USD': 4.11, 'EUR':5.25, 'ARS':0.0026, 'CHF':4.75}

# %% [markdown]
# **9.- Escribir un programa que almacene los vectores (1,2,3) y (-1,0,2) en dos listas y muestre por pantalla su producto escalar.**

# %%
## Resolver Aqui

# %% [markdown]
# **10.-Crear la matriz y obtener los datos de colores**![image.png](data:image/png;base64,...)

# %%
## Resolver aqui
